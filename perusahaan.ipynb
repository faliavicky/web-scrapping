# %%
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# %%
options = Options()
options.add_argument("window-size=1400,600")
from fake_useragent import UserAgent

# %%
ua = UserAgent()
a = ua.random
user_agent = ua.random
print(user_agent)
options.add_argument(f'user-agent={user_agent}')
# Out:
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36 Edg/117.0.2045.41

# %%
driver = Chrome()
driver.get('https://klikalamat.com/edukasi-kursus/')

# %%
import time

time.sleep(10)

# %%
page = 2
nama = []
nomor = []
alamat = []

# %%
while True:
        time.sleep(10)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        web = soup.find_all("section", {'class':'search_result_listing list'})
        web_nama = soup.find_all(attrs={'class':'entry-title'})
        web_nomor = soup.find_all('p',attrs={'class':'phone'})
        web_alamat = soup.find_all(attrs={'class':'address'})

        for element_nama in web_nama:
                nama.append(element_nama.text)

        for element_nomor in web_nomor:
                nomor.append(element_nomor.text)

        for element_alamat in web_alamat:
                alamat.append(element_alamat.text)

        if len(driver.find_elements(By.CLASS_NAME, 'page-numbers')) > 0:
                url = "https://klikalamat.com/edukasi-kursus/page/{}/".format(page)
                driver.get(url)
                page += 1
        else:
              break
        
'''
        for results in soup:
            nama.append(soup.find(attrs={'class':'entry-title'}).get_text().strip())
            nomor.append(soup.find('p', attrs={'class':'phone'}).get_text().strip())
            alamat.append(soup.find(attrs={'class':'address'}).get_text().strip())'''
# Out:
# ['PT. Securiko Indonesia', 'PT. Indo Artha Multitek', 'Kartika Sejati', 'Design Solusi', '88English', 'Kursus Komputer untuk Pemula', 'Talenta MJP', 'Cyberhair Youth Salon', 'Irwan Team Hair Design', 'Multikom', 'BABA STUDIO', 'Rumah Batik Jawa Timur']
# ['0313713418', '0816855216', '8129895476', '0812245007', '0614535788', '0225410182', '(022) 7537999', '02172792750', '0217506747', '0217800125', '02153664008', '0318499346']
# ...

# %%
df = pd.DataFrame(nomor)
df
# Out:
#                                                     0
# 0                                          0313713418
# 1                                          0816855216
# 2                                          8129895476
# 3                                          0812245007
# 4                                          0614535788
# 5                                          0225410182
# 6                                       (022) 7537999
# 7                                         02172792750
# 8                                          0217506747
# 9                                          0217800125
# 10                                        02153664008
# 11                                         0318499346
# 12                                      (022) 7272494
# 13                                        022-4238738
# 14                                     0813-9514-0214
# 15                                  +62 857-1019-8721
# ...

# %%
web_nama = soup.find_all(attrs={'class':'entry-title'})
web_nomor = soup.find_all('p',attrs={'class':'phone'})
web_alamat = soup.find_all(attrs={'class':'address'})
nama = []
nomor = []
alamat = []

# %%
for element in web_nama:
        nama.append(element.text)
print(nama)

for element in web_nomor:
        nomor.append(element.text)
print(nomor)

for element in web_alamat:
        alamat.append(element.text)
print(alamat)
# Out:
# ['PT. Securiko Indonesia', 'PT. Indo Artha Multitek', 'Kartika Sejati', 'Design Solusi', '88English', 'Kursus Komputer untuk Pemula', 'Talenta MJP', 'Cyberhair Youth Salon', 'Irwan Team Hair Design', 'Multikom', 'BABA STUDIO', 'Rumah Batik Jawa Timur']
# ['0313713418', '0816855216', '8129895476', '0812245007', '0614535788', '0225410182', '(022) 7537999', '02172792750', '0217506747', '0217800125', '02153664008', '0318499346']
# ...

# %%
print(len(alamat))
# Out:
# 12

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Perusahaan':nama, 'Nomor':nomor, 'Alamat':alamat})

# %%
df
# Out:
#                       Perusahaan          Nomor  \
# 0         PT. Securiko Indonesia     0313713418
# 1        PT. Indo Artha Multitek     0816855216
# 2                 Kartika Sejati     8129895476
# 3                  Design Solusi     0812245007
# 4                      88English     0614535788
# 5   Kursus Komputer untuk Pemula     0225410182
# 6                    Talenta MJP  (022) 7537999
# 7          Cyberhair Youth Salon    02172792750
# 8         Irwan Team Hair Design     0217506747
# 9                       Multikom     0217800125
# 10                   BABA STUDIO    02153664008
# 11        Rumah Batik Jawa Timur     0318499346
#
#                                                Alamat
# 0   Komplek Ruko Atom Megah, Jl. Gembong No. 32K ,...
# 1   Gedung BITC Jl. HMS Mintareja Baros CImahi Ten...
# 2   Jl. Villa Bukit Tidar Blok E2 No.308, Jenglong...
# 3   Cangkuang, Ciluncat, Bandung, West Java, Indon...
# 4   Wisma BII, Jalan Pangeran Diponegoro, Madras H...
# ...
